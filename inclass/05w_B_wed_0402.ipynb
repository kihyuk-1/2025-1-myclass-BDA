# %% [markdown]
# <a href="https://colab.research.google.com/github/kihyuk-1/2025-1-myclass-BDA/blob/main/inclass/05w_B_wed_0402.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_new.rename(index = {0 : 'x' , 1 : 'y' , 2 : 'z'}.inplace
              )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-539f81cd0e5a> in <cell line: 0>()
# ----> 1 df_new.rename(index = {0 : 'x' , 1 : 'y' , 2 : 'z'}.inplace
#       2               )
#
# NameError: name 'df_new' is not defined

# %% [markdown]
# ## 파생변수 생성

# %%
df = pd.DataFrame({'var1' : [4,3,8] ,
                   'var2' :  [2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1['var1'] + df1['var2']

# %%
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_mean'] = (df1['var1'] + df1['var2']) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum(axis=0)
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['var_sum'] = df2.sum(axis=1)
df2
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df2['var_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  var_sum
# 0     4     2       12
# 1     3     6       18
# 2     8     1       18

# %%
df2[['var1' , 'var2']]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2[['var1' , 'var2']].mean()
# Out:
# var1    5.0
# var2    3.0
# dtype: float64

# %%
df2[['var1' , 'var2']].mean(axis=1)
# Out:
# 0    3.0
# 1    4.5
# 2    4.5
# dtype: float64

# %%
df2['var_mean'] = df2[['var1' , 'var2']].mean(axis=1)

# %%
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %% [markdown]
# ## mpg 통합 연비 변수 만들기

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-59186b584ac7> in <cell line: 0>()
# ----> 1 mpg = pd.read_csv('data/mpg.csv')
#       2 mpg.info()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/mpg.csv'

# %%
mpg['total'] = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-88514d4b07f0> in <cell line: 0>()
# ----> 1 mpg['total'] = (mpg.cty + mpg.hwy) / 2
#       2 mpg.head()
#
# NameError: name 'mpg' is not defined

# %%
mpg['mpg_mean'] = mpg[['cty' , 'hwy']].mean(axis='colums')
mpg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-de4ee0dc1b1f> in <cell line: 0>()
# ----> 1 mpg['mpg_mean'] = mpg[['cty' , 'hwy']].mean(axis='colums')
#       2 mpg.head()
#
# NameError: name 'mpg' is not defined

# %%
mpg.total
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4a03d53c0dfb> in <cell line: 0>()
# ----> 1 mpg.total
#
# NameError: name 'mpg' is not defined

# %%
sum(mpg.total) / len(mpg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-01448a41846e> in <cell line: 0>()
# ----> 1 sum(mpg.total) / len(mpg)
#
# NameError: name 'mpg' is not defined

# %%
mpg['total'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-8a61eb70a677> in <cell line: 0>()
# ----> 1 mpg['total'].mean()
#
# NameError: name 'mpg' is not defined

# %% [markdown]
# ## 조건문 활용

# %%
mpg.total.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2abe7af255e1> in <cell line: 0>()
# ----> 1 mpg.total.describe()
#
# NameError: name 'mpg' is not defined

# %%
mpg.total.plot.hist();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8873cbe16176> in <cell line: 0>()
# ----> 1 mpg.total.plot.hist();
#
# NameError: name 'mpg' is not defined

# %%
import koreanize_matplotlib

# %%
mpg['total'].plot(kind="hist", title="히스토그램");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-af54198e5358> in <cell line: 0>()
# ----> 1 mpg['total'].plot(kind="hist", title="히스토그램");
#
# NameError: name 'mpg' is not defined

# %%
import koreanize_matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-488673125e05> in <cell line: 0>()
# ----> 1 import koreanize_matplotlib
#
# ModuleNotFoundError: No module named 'koreanize_matplotlib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
mpg['total'].plot(kind="hist", title="히스토그램");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-35fb93d69ab7> in <cell line: 0>()
# ----> 1 mpg['total`1'].plot(kind="hist", title="히스토그램");
#
# NameError: name 'mpg' is not defined

# %%
import seaborn as sns
sns,histplot(mpg , x='total');
